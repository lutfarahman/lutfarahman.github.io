# %%
# Task-1

# %% [markdown]
# |$\psi$> = |+>= $\frac{1}{\sqrt(2)}$ (|0> + |1>)
# After encoding, |$\psi$> |00> = $\frac{1}{\sqrt(2)}$ (|000> + |111>)
# So, by applying C-NOT gate we can get this encoding. For example, when CNOT is applied between |$\psi$> and 2nd qubit,
# we get = $\frac{1}{\sqrt(2)}$ (|00> + |11>) . Similarly, when CNOT is applied between |$\psi$> and 3rd qubit,
# we get = $\frac{1}{\sqrt(2)}$ (|000> + |111>)
#
# And for |-> = |$\psi$> = $\frac{1}{\sqrt(2)}$ (|0> - |1>)
# After encoding, |$\psi$> |00> = $\frac{1}{\sqrt(2)}$ (|000> - |111>)
#
# ![image.png](attachment:4e0456b1-b732-4274-a9e5-afd4edecba60.png)

# %%
# Task-2

# %% [markdown]
# ![image.png](attachment:c6ced3be-4683-4831-8f73-47de8e42f531.png)
# ![image.png](attachment:e80d6f3b-07cf-458e-878b-7a69e05caf37.png)

# %% [markdown]
# $\bar{X}$ means NOT gate is applied 3 times. So, $\bar{X}$ |000> = |111>.
# For example, if X is applied of |0>, we get |1>. We can do this just by matrix multiplication.
# Similarly, if Z is applied of |1>, we get |-1>

# %%
#Task-3

# %% [markdown]
# ![image.png](attachment:d4825d00-2f8d-47e8-adbc-7fe6ccdebefc.png)
# ![image.png](attachment:8916a86f-821f-4a63-b569-6233dec30ab7.png)

# %% [markdown]
# Do different errors result in the same output state?
# #### NO

# %%
### Question-1:* Fill the ? in the table above.

# %% [markdown]
# Alice sends the three data qubits through the noisy channel. Each of them will have probability $p$ of being flipped. If the second qubit is flipped, then Bob receives the state $X_2\ket{\bar\psi} = \ket{\tilde\psi} = \alpha\ket{010} + \beta\ket{101}$. In total there, are eight possiblities for the error, with the probabilities similar to the classical case.
#
# |  Error       | Probability |
# |:------------:|:-----------:|
# |  $I$         | $(1-p)^3$   |
# |  $X_0$       | $p(1-p)^2$  |
# |  $X_1$       | $p(1-p)^2$  |
# |  $X_2$       | $p(1-p)^2$  |
# |  $X_0X_1$    | $(p)^2 (1-p)$         |
# |  $X_0X_2$    | $(p)^2 (1-p)$         |
# |  $X_1X_2$    | $(p)^2 (1-p)$         |
# |  $X_0X_1X_2$ | $p^3$       |

# %% [markdown]
# *Question-2:* Above, we have shown how row 1 and row 3 of the table are obtained. Work out the other two rows by hand.

# %% [markdown]
# |  Syndrome | Inferred error |
# |:---------:|:--------------:|
# |  $00$     | $I$            |
# |  $01$     | $X_3$          |
# |  $10$     | $X_1$          |
# |  $11$     | $X_2$          |

# %% [markdown]
# #### Unsolved

# %% [markdown]
# Question: Consider the 5-qubit repetition code, in which the coding operates in a similar fashion as the 3-qubit one we have discussed,
# but with five qubits instead of three.
# Can this larger code possibly correct errors in which two qubits are flipped?

# %% [markdown]
# #### Unsolved

# %% [markdown]
# *Question:* Recall that a vector subspace is characterized by a projector $\Pi = \sum_i \ket{\psi_i}\bra{\psi_i}$, where $\set{\ket{\psi_i}}_i$ is a basis for the subspace. Show that $\Pi^2 = \Pi$.
#
# $\Pi^2 = \sum_i (\ket{\psi_i}\bra{\psi_i})^2 $ = $\sum_i \ket{\psi_i} <{\psi_i}|{\psi_i}> \bra{\psi_i}$ = $\Pi$

# %%
Question: Determine the projector onto the code for the three-qubit code.

# %% [markdown]
# For, $\ket{\psi_i} = \alpha \ket {000} + \beta \ket {111}$
# Taking Projection, $\Pi = \sum_i \ket{\psi_i}\bra{\psi_i}$
# = ($\alpha \ket {000} + \beta \ket {111}) (\alpha \bra {000} + \beta \bra {111})$ = $\alpha^2 |000> <000| + \beta^2 |111> <111| + \alpha \beta |000> <111| +  \alpha \beta |111> <000|$

# %% [markdown]
# ##### Correct answers
# ![image.png](attachment:9a47a6be-8814-43da-9ec2-9ce63e32da3a.png)
